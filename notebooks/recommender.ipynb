# %% [markdown]
# # Configurations

# %%
import ast
import pandas as pd
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer
from sklearn.metrics.pairwise import cosine_similarity
import nltk

# %%
DATA_DIRECTORY = "../data/raw/"

# %%
def show(data):
    print(data.shape)
    display(data.head(3))

# %%
def clean_data(x):
    return [i.lower().replace(" ", "") for i in x] if x is not pd.NA else ""

# %% [markdown]
# # Data Acquisition

# %%
top_rated_movies = pd.read_csv(DATA_DIRECTORY + "tmdb/top_rated_movies_english.csv")
show(top_rated_movies)
# Out:
# (9031, 14)
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg  [18, 80]  238                en
# 1  False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg  [18, 80]  278                en
# 2  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg  [18, 80]  240                en
#
#              original_title  \
# 0             The Godfather
# 1  The Shawshank Redemption
# 2     The Godfather Part II
#
#                                             overview  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...     160.502
# 1  Framed in the 1940s for the double murder of h...     150.884
# 2  In the continuing saga of the Corleone crime f...      87.692
#
#                         poster_path release_date                     title  \
# 0  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-07-07             The Godfather
# 1  /q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg   1995-03-17  The Shawshank Redemption
# 2  /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1975-02-14     The Godfather Part II
#
#    video  vote_average  vote_count
# 0  False         8.700       19184
# 1  False         8.700       25170
# 2  False         8.589       11563

# %%
omdb_data = pd.read_csv(DATA_DIRECTORY + "omdb/data.csv")
show(omdb_data)
# Out:
# (7815, 26)
#              Title  Year      Rated     Released  Runtime  \
# 0    The Immigrant  2013          R  23 May 2014  120 min
# 1  Happy Death Day  2017      PG-13  13 Oct 2017   96 min
# 2          Persona  1966  Not Rated  16 Mar 1967   83 min
#
#                      Genre            Director                   Writer  \
# 0           Drama, Romance          James Gray  James Gray, Ric Menello
# 1  Comedy, Horror, Mystery  Christopher Landon            Scott Lobdell
# 2          Drama, Thriller      Ingmar Bergman           Ingmar Bergman
#
#                                              Actors  \
# 0  Marion Cotillard, Joaquin Phoenix, Jeremy Renner
# 1      Jessica Rothe, Israel Broussard, Ruby Modine
# 2     Bibi Andersson, Liv Ullmann, Margaretha Krook
#
#                                                 Plot  ... imdbRating  \
# 0  1921. In search of a new start and the America...  ...        6.6
# 1  A teenage girl, trying to enjoy her birthday, ...  ...        6.6
# 2  A young nurse, Alma, is put in charge of Elisa...  ...        8.1
#
#   imdbVotes     imdbID   Type          DVD    BoxOffice  Production Website  \
# 0    33,296  tt1951181  movie  20 Feb 2015   $2,025,328         NaN     NaN
# 1   158,561  tt5308322  movie  02 Jan 2018  $55,683,845         NaN     NaN
# 2   128,047  tt0060827  movie  11 Mar 2017          NaN         NaN     NaN
#
#   Response                        Time
# 0     True  2023-12-25 10:00:28.706861
# 1     True  2023-12-25 10:00:29.119556
# 2     True  2023-12-25 10:00:29.519696
#
# [3 rows x 26 columns]

# %%
keywords = pd.read_csv(DATA_DIRECTORY + "tmdb/keywords.csv")
show(keywords)
# Out:
# (9025, 2)
#     id                                           keywords
# 0  238  ['based on novel or book', 'loss of loved one'...
# 1  278  ['prison', 'friendship', 'police brutality', '...
# 2  240  ['italian american', 'cuba', 'italy', 'gangste...

# %%
additional_info = pd.read_csv(DATA_DIRECTORY + "tmdb/additional_info.csv")
show(additional_info)
# Out:
# (9025, 7)
#     id    budget    revenue    imdb_id  runtime  \
# 0  238   6000000  245066411  tt0068646      175
# 1  278  25000000   28341469  tt0111161      142
# 2  240  13000000  102600000  tt0071562      202
#
#                                              tagline production_countries
# 0                         An offer you can't refuse.                   US
# 1  Fear can hold you prisoner. Hope can set you f...                   US
# 2                                                NaN                   US

# %%
genres = pd.read_csv(DATA_DIRECTORY + "tmdb/genres.csv")
show(genres)
# Out:
# (19, 2)
#    id       name
# 0  28     Action
# 1  12  Adventure
# 2  16  Animation

# %%
movies_providers = pd.read_csv(DATA_DIRECTORY + "tmdb/movie_providers.csv")
show(movies_providers)
# Out:
# (34403, 4)
#     id                                               link transaction_type  \
# 0  238  https://www.themoviedb.org/movie/238-the-godfa...             rent
# 1  238  https://www.themoviedb.org/movie/238-the-godfa...             rent
# 2  238  https://www.themoviedb.org/movie/238-the-godfa...             rent
#
#    provider_id
# 0          167
# 1            2
# 2           10

# %%
provider_id = 8
movies_providers[movies_providers["provider_id"] == provider_id]["id"]
# Out:
# 47          129
# 94          680
# 140      568332
# 155         550
# 172         598
#           ...
# 34201    407559
# 34302    351460
# 34381     22345
# 34385    505423
# 34397    485774
# Name: id, Length: 1115, dtype: int64

# %% [markdown]
# # Preprocessing

# %%
raw_data = (
    top_rated_movies[["id", "title", "overview", "genre_ids", "release_date"]]
    .merge(keywords[["id", "keywords"]], how="left", on="id")
    .merge(additional_info[["id", "tagline", "imdb_id"]], how="left", on="id")
    .merge(
        omdb_data[["imdbID", "Director", "Writer", "Actors"]],
        how="left",
        left_on="imdb_id",
        right_on="imdbID",
    )
)


show(raw_data)
# Out:
# (9031, 12)
#     id                     title  \
# 0  238             The Godfather
# 1  278  The Shawshank Redemption
# 2  240     The Godfather Part II
#
#                                             overview genre_ids release_date  \
# 0  Spanning the years 1945 to 1955, a chronicle o...  [18, 80]   1972-07-07
# 1  Framed in the 1940s for the double murder of h...  [18, 80]   1995-03-17
# 2  In the continuing saga of the Corleone crime f...  [18, 80]   1975-02-14
#
#                                             keywords  \
# 0  ['based on novel or book', 'loss of loved one'...
# 1  ['prison', 'friendship', 'police brutality', '...
# 2  ['italian american', 'cuba', 'italy', 'gangste...
#
#                                              tagline    imdb_id     imdbID  \
# 0                         An offer you can't refuse.  tt0068646  tt0068646
# 1  Fear can hold you prisoner. Hope can set you f...  tt0111161  tt0111161
# 2                                                NaN  tt0071562  tt0071562
#
#                Director                            Writer  \
# 0  Francis Ford Coppola  Mario Puzo, Francis Ford Coppola
# 1        Frank Darabont      Stephen King, Frank Darabont
# 2  Francis Ford Coppola  Francis Ford Coppola, Mario Puzo
#
#                                      Actors
# 0      Marlon Brando, Al Pacino, James Caan
# 1   Tim Robbins, Morgan Freeman, Bob Gunton
# 2  Al Pacino, Robert De Niro, Robert Duvall

# %%
genre_data = raw_data.copy()
genres_map = genres.set_index("id").to_dict()["name"]
mapped_genres = (
    genre_data[["id", "genre_ids"]]
    .set_index("id")["genre_ids"]
    .apply(ast.literal_eval)
    .explode()
    .replace(genres_map)
    .astype("str")
)
genres_column = mapped_genres.groupby(mapped_genres.index).agg(", ".join).reset_index()
genre_data = genre_data.merge(genres_column, how="left", on="id", suffixes=("_drop", ""))

genre_data = genre_data.drop(["genre_ids_drop", "release_date", "imdb_id", "imdbID"], axis=1)

genre_data = genre_data.rename(
    {"Director": "directors", "Writer": "writers", "Actors": "actors", "genre_ids": "genres"}, axis=1
)

show(genre_data)
# Out:
# (9031, 9)
#     id                     title  \
# 0  238             The Godfather
# 1  278  The Shawshank Redemption
# 2  240     The Godfather Part II
#
#                                             overview  \
# 0  Spanning the years 1945 to 1955, a chronicle o...
# 1  Framed in the 1940s for the double murder of h...
# 2  In the continuing saga of the Corleone crime f...
#
#                                             keywords  \
# 0  ['based on novel or book', 'loss of loved one'...
# 1  ['prison', 'friendship', 'police brutality', '...
# 2  ['italian american', 'cuba', 'italy', 'gangste...
#
#                                              tagline             directors  \
# 0                         An offer you can't refuse.  Francis Ford Coppola
# 1  Fear can hold you prisoner. Hope can set you f...        Frank Darabont
# 2                                                NaN  Francis Ford Coppola
#
#                             writers                                    actors  \
# 0  Mario Puzo, Francis Ford Coppola      Marlon Brando, Al Pacino, James Caan
# 1      Stephen King, Frank Darabont   Tim Robbins, Morgan Freeman, Bob Gunton
# 2  Francis Ford Coppola, Mario Puzo  Al Pacino, Robert De Niro, Robert Duvall
#
#          genres
# 0  Drama, Crime
# 1  Drama, Crime
# 2  Drama, Crime

# %%
nl_data = genre_data.copy()
ps = PorterStemmer()

nl_data["keywords"] = nl_data["keywords"].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [""])

tokenizer = RegexpTokenizer(r"\w+")
nl_data["overview"] = nl_data["overview"].astype(str).apply(lambda x: tokenizer.tokenize(x))
nl_data["tagline"] = nl_data["tagline"].astype(str).apply(lambda x: tokenizer.tokenize(x))

to_list = ["genres", "actors", "writers", "directors"]
for feature in to_list:
    nl_data[feature] = nl_data[feature].astype(str).apply(lambda x: x.split(",") if x != "" else pd.NA)

stopwords = nltk.corpus.stopwords.words("english")
stem_stopwords = ["keywords", "overview", "tagline"]
for feature in stem_stopwords:
    nl_data[feature] = nl_data[feature].apply(
        lambda x: [ps.stem(word) for words in x for word in words.split() if word.lower() not in stopwords]
    )

to_clean = ["keywords", "directors", "writers", "actors", "genres"]
for feature in to_clean:
    nl_data[feature] = nl_data[feature].apply(clean_data)


def create_soup_plot(x):
    return f"{' '.join(x['overview'])} {' '.join(x['tagline'])}"


def create_soup_general(x):
    return f"{' '.join(x['keywords'])} {' '.join(x['directors'])} {' '.join(x['writers'])} {' '.join(x['actors'])} {' '.join(x['genres'])}"


nl_data["soup_plot"] = nl_data.apply(create_soup_plot, axis=1)
nl_data["soup_general"] = nl_data.apply(create_soup_general, axis=1)
show(nl_data)
# Out:
# (9031, 11)
#     id                     title  \
# 0  238             The Godfather
# 1  278  The Shawshank Redemption
# 2  240     The Godfather Part II
#
#                                             overview  \
# 0  [span, year, 1945, 1955, chronicl, fiction, it...
# 1  [frame, 1940, doubl, murder, wife, lover, upst...
# 2  [continu, saga, corleon, crime, famili, young,...
#
#                                             keywords  \
# 0  [base, novel, book, loss, love, one, love, fir...
# 1  [prison, friendship, polic, brutal, corrupt, b...
# 2  [italian, american, cuba, itali, gangster, pra...
#
#                                  tagline             directors  \
# 0                         [offer, refus]  [francisfordcoppola]
# 1  [fear, hold, prison, hope, set, free]       [frankdarabont]
# 2                                  [nan]  [francisfordcoppola]
#
#                            writers                                  actors  \
# 0  [mariopuzo, francisfordcoppola]     [marlonbrando, alpacino, jamescaan]
# 1     [stephenking, frankdarabont]  [timrobbins, morganfreeman, bobgunton]
# 2  [francisfordcoppola, mariopuzo]  [alpacino, robertdeniro, robertduvall]
#
#            genres                                          soup_plot  \
# 0  [drama, crime]  span year 1945 1955 chronicl fiction italian a...
# 1  [drama, crime]  frame 1940 doubl murder wife lover upstand ban...
# 2  [drama, crime]  continu saga corleon crime famili young vito c...
#
#                                         soup_general
# 0  base novel book loss love one love first sight...
# 1  prison friendship polic brutal corrupt base no...
# 2  italian american cuba itali gangster prais sym...

# %%
count_vectorizer = CountVectorizer(stop_words="english")

# %%
plot_matrix = count_vectorizer.fit_transform(nl_data["soup_plot"])
general_matrix = count_vectorizer.fit_transform(nl_data["soup_general"])
plot_similarity = cosine_similarity(plot_matrix, plot_matrix)
general_similarity = cosine_similarity(general_matrix, general_matrix)

weight_plot = 0.5
result_similarity = weight_plot * plot_similarity + (1 - weight_plot) * general_similarity

# %%
indices = pd.Series(nl_data.index, index=nl_data["title"])

# %%
[movie for movie in list(nl_data["title"]) if movie.startswith("Fear Street")]
# Out:
# ['Fear Street: 1978', 'Fear Street: 1666', 'Fear Street: 1994']

# %%
title = "Fear Street: 1994"

idx = indices[title]

scores = list(enumerate(result_similarity[idx]))
scores = sorted(scores, key=lambda x: x[1], reverse=True)

movies = [score[0] for score in scores]
nl_data["title"].iloc[movies]
# Out:
# 4265                 Fear Street: 1994
# 2487                 Fear Street: 1666
# 2232                 Fear Street: 1978
# 7065    Percy Jackson: Sea of Monsters
# 7309                      Solomon Kane
#                      ...
# 9011                     Baby Geniuses
# 9013                        Rollerball
# 9018                        Epic Movie
# 9023        Lucky Luke and the Daltons
# 9026                    Disaster Movie
# Name: title, Length: 9031, dtype: object
